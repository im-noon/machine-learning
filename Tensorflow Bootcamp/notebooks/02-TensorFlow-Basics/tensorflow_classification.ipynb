# %% [markdown]
# # TensorFlow Classification

# %% [markdown]
# ## Data
#
# https://archive.ics.uci.edu/ml/datasets/pima+indians+diabetes
#
# 1. Title: Pima Indians Diabetes Database
#
# 2. Sources:
#    (a) Original owners: National Institute of Diabetes and Digestive and
#                         Kidney Diseases
#    (b) Donor of database: Vincent Sigillito (vgs@aplcen.apl.jhu.edu)
#                           Research Center, RMI Group Leader
#                           Applied Physics Laboratory
#                           The Johns Hopkins University
#                           Johns Hopkins Road
#                           Laurel, MD 20707
#                           (301) 953-6231
#    (c) Date received: 9 May 1990
#
# 3. Past Usage:
#     1. Smith,~J.~W., Everhart,~J.~E., Dickson,~W.~C., Knowler,~W.~C., \&
#        Johannes,~R.~S. (1988). Using the ADAP learning algorithm to forecast
#        the onset of diabetes mellitus.  In {\it Proceedings of the Symposium
#        on Computer Applications and Medical Care} (pp. 261--265).  IEEE
#        Computer Society Press.
#
#        The diagnostic, binary-valued variable investigated is whether the
#        patient shows signs of diabetes according to World Health Organization
#        criteria (i.e., if the 2 hour post-load plasma glucose was at least
#        200 mg/dl at any survey  examination or if found during routine medical
#        care).   The population lives near Phoenix, Arizona, USA.
#
#        Results: Their ADAP algorithm makes a real-valued prediction between
#        0 and 1.  This was transformed into a binary decision using a cutoff of
#        0.448.  Using 576 training instances, the sensitivity and specificity
#        of their algorithm was 76% on the remaining 192 instances.
#
# 4. Relevant Information:
#       Several constraints were placed on the selection of these instances from
#       a larger database.  In particular, all patients here are females at
#       least 21 years old of Pima Indian heritage.  ADAP is an adaptive learning
#       routine that generates and executes digital analogs of perceptron-like
#       devices.  It is a unique algorithm; see the paper for details.
#
# 5. Number of Instances: 768
#
# 6. Number of Attributes: 8 plus class
#
#     7. For Each Attribute: (all numeric-valued)
#        1. Number of times pregnant
#        2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#        3. Diastolic blood pressure (mm Hg)
#        4. Triceps skin fold thickness (mm)
#        5. 2-Hour serum insulin (mu U/ml)
#        6. Body mass index (weight in kg/(height in m)^2)
#        7. Diabetes pedigree function
#        8. Age (years)
#        9. Class variable (0 or 1)
#
# 8. Missing Attribute Values: Yes
#
# 9. Class Distribution: (class value 1 is interpreted as "tested positive for
#    diabetes")
#
#    Class Value  Number of instances
#    0            500
#    1            268
#
# 10. Brief statistical analysis:
#
#         Attribute number:    Mean:   Standard Deviation:
#         1.                     3.8     3.4
#         2.                   120.9    32.0
#         3.                    69.1    19.4
#         4.                    20.5    16.0
#         5.                    79.8   115.2
#         6.                    32.0     7.9
#         7.                     0.5     0.3
#         8.                    33.2    11.8

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('../data/pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %% [markdown]
# ### Clean the Data

# %%
col_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[col_to_norm] = diabetes[col_to_norm].apply(lambda x:(x - x.min())/(x.max()-x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %% [markdown]
# ### Feature Columns

# %%
import tensorflow as tf

# %% [markdown]
# ### Continuous Features
#
# * Number of times pregnant
# * Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * Diastolic blood pressure (mm Hg)
# * Triceps skin fold thickness (mm)
# * 2-Hour serum insulin (mu U/ml)
# * Body mass index (weight in kg/(height in m)^2)
# * Diabetes pedigree function

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %% [markdown]
# ### Categorical Features

# %% [markdown]
# If you know the set of all possible feature values of a column and there are only a few of them, you can use categorical_column_with_vocabulary_list. If you don't know the set of possible values in advance you can use categorical_column_with_hash_bucket

# %%
# using vocab list
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A', 'B', 'C', 'D'])

# %%
# using hassh bucket
# assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)

# %% [markdown]
# ### Converting Continuous to Categorical

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_bucket = tf.feature_column.bucketized_column(age, boundaries=[20, 30, 40, 50, 60, 70, 80])

# %% [markdown]
# ### Putting them together

# %%
feat_cols = [num_preg, 
             plasma_gluc, 
             dias_press, 
             tricep, 
             insulin, 
             bmi, 
             diabetes_pedigree, 
             assigned_group, 
             age_bucket]

# %% [markdown]
# ### Train Test Split

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
# Number_pregnant          768 non-null float64
# Glucose_concentration    768 non-null float64
# Blood_pressure           768 non-null float64
# Triceps                  768 non-null float64
# Insulin                  768 non-null float64
# BMI                      768 non-null float64
# Pedigree                 768 non-null float64
# Age                      768 non-null int64
# Class                    768 non-null int64
# Group                    768 non-null object
# dtypes: float64(7), int64(2), object(1)
# memory usage: 60.1+ KB

# %%
x_data = diabetes.drop('Class', axis=1)

# %%
x_data.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age Group
# 0  0.500745  0.234415   50     B
# 1  0.396423  0.116567   31     C
# 2  0.347243  0.253629   32     B
# 3  0.418778  0.038002   21     B
# 4  0.642325  0.943638   33     C

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,
                                                    labels, 
                                                    test_size=0.3, 
                                                    random_state=101)

# %% [markdown]
# ### Input Function

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train, 
                                                 y=y_train, 
                                                 batch_size=10, 
                                                 num_epochs=1000,
                                                 shuffle=True)

# %% [markdown]
# ### Creating the Model

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols, n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/j8/4vht5fhd3rg9wv8rx18tt20c0000gp/T/tmpl8evndyo
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/j8/4vht5fhd3rg9wv8rx18tt20c0000gp/T/tmpl8evndyo', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x138e7e9b0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func,steps=1000)
# Out:
# WARNING:tensorflow:From /Users/Slimn/anaconda3/envs/tfdl/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/Slimn/anaconda3/envs/tfdl/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /Users/Slimn/anaconda3/envs/tfdl/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /Users/Slimn/anaconda3/envs/tfdl/lib/python3.7/site-packages/tensorflow/python/feature_column/feature_column_v2.py:2703: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /Users/Slimn/anaconda3/envs/tfdl/lib/python3.7/site-packages/tensorflow/python/feature_column/feature_column_v2.py:2898: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /Users/Slimn/anaconda3/envs/tfdl/lib/python3.7/site-packages/tensorflow/python/training/monitored_session.py:809: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/j8/4vht5fhd3rg9wv8rx18tt20c0000gp/T/tmpl8evndyo/model.ckpt.
# INFO:tensorflow:loss = 6.931472, step = 1
# INFO:tensorflow:global_step/sec: 57.1481
# INFO:tensorflow:loss = 7.9450173, step = 101 (1.759 sec)
# INFO:tensorflow:global_step/sec: 114.457
# INFO:tensorflow:loss = 4.2753487, step = 201 (0.886 sec)
# INFO:tensorflow:global_step/sec: 102.75
# INFO:tensorflow:loss = 4.761093, step = 301 (0.957 sec)
# INFO:tensorflow:global_step/sec: 102.753
# INFO:tensorflow:loss = 4.60321, step = 401 (0.971 sec)
# INFO:tensorflow:global_step/sec: 105.781
# INFO:tensorflow:loss = 6.0485106, step = 501 (0.949 sec)
# INFO:tensorflow:global_step/sec: 108.312
# INFO:tensorflow:loss = 7.230063, step = 601 (0.924 sec)
# INFO:tensorflow:global_step/sec: 117.912
# INFO:tensorflow:loss = 4.4487348, step = 701 (0.844 sec)
# INFO:tensorflow:global_step/sec: 100.4
# INFO:tensorflow:loss = 5.1369257, step = 801 (1.003 sec)
# INFO:tensorflow:global_step/sec: 87.8669
# INFO:tensorflow:loss = 6.4064574, step = 901 (1.139 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/j8/4vht5fhd3rg9wv8rx18tt20c0000gp/T/tmpl8evndyo/model.ckpt.
# INFO:tensorflow:Loss for final step: 6.0548477.

# %% [markdown]
# ## Evaluation

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test,
                                                      y=y_test,
                                                      batch_size=10,
                                                      num_epochs=1,
                                                      shuffle=False)

# %%
result = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /Users/Slimn/anaconda3/envs/tfdl/lib/python3.7/site-packages/tensorflow/python/ops/metrics_impl.py:2002: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-06T01:59:32Z
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /Users/Slimn/anaconda3/envs/tfdl/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /var/folders/j8/4vht5fhd3rg9wv8rx18tt20c0000gp/T/tmpl8evndyo/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-06-06-01:59:36
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.74025977, accuracy_baseline = 0.64935064, auc = 0.8039917, auc_precision_recall = 0.64873946, average_loss = 0.5253391, global_step = 1000, label/mean = 0.35064936, loss = 5.0563893, precision = 0.65217394, prediction/mean = 0.37339875, recall = 0.5555556
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /var/folders/j8/4vht5fhd3rg9wv8rx18tt20c0000gp/T/tmpl8evndyo/model.ckpt-1000

# %%
result
# Out:
# {'accuracy': 0.74025977,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.8039917,
#  'auc_precision_recall': 0.64873946,
#  'average_loss': 0.5253391,
#  'label/mean': 0.35064936,
#  'loss': 5.0563893,
#  'precision': 0.65217394,
#  'prediction/mean': 0.37339875,
#  'recall': 0.5555556,
#  'global_step': 1000}

# %% [markdown]
# ## Predictions

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test,
                                                      batch_size=10, 
                                                      num_epochs=1, 
                                                      shuffle=False)

# %%
predictions = model.predict(pred_input_func)

# %%
list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/j8/4vht5fhd3rg9wv8rx18tt20c0000gp/T/tmpl8evndyo/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'logits': array([0.12879157], dtype=float32),
#   'logistic': array([0.5321534], dtype=float32),
#   'probabilities': array([0.46784657, 0.5321535 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.5740763], dtype=float32),
#   'logistic': array([0.6397032], dtype=float32),
#   'probabilities': array([0.3602968, 0.6397033], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.4880718], dtype=float32),
#   'logistic': array([0.3803479], dtype=float32),
#   'probabilities': array([0.6196521, 0.3803479], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.5959315], dtype=float32),
#   'logistic': array([0.35527503], dtype=float32),
#   'probabilities': array([0.64472497, 0.3552751 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6823328], dtype=float32),
#   'logistic': array([0.15678683], dtype=float32),
#   'probabilities': array([0.8432132 , 0.15678681], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.8475075], dtype=float32),
#   'logistic': array([0.70004404], dtype=float32),
#   'probabilities': array([0.299956  , 0.70004404], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.44939256], dtype=float32),
#   'logistic': array([0.6104948], dtype=float32),
#   'probabilities': array([0.3895052 , 0.61049485], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.72057056], dtype=float32),
#   'logistic': array([0.32726735], dtype=float32),
#   'probabilities': array([0.67273265, 0.32726735], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0962931], dtype=float32),
#   'logistic': array([0.25043508], dtype=float32),
#   'probabilities': array([0.7495649 , 0.25043508], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1176671], dtype=float32),
#   'logistic': array([0.24644427], dtype=float32),
#   'probabilities': array([0.7535557 , 0.24644427], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7935011], dtype=float32),
#   'logistic': array([0.14264399], dtype=float32),
#   'probabilities': array([0.857356, 0.142644], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5855536], dtype=float32),
#   'logistic': array([0.17001039], dtype=float32),
#   'probabilities': array([0.8299896 , 0.17001039], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.8661236], dtype=float32),
#   'logistic': array([0.29606158], dtype=float32),
#   'probabilities': array([0.7039385 , 0.29606155], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.29262483], dtype=float32),
#   'logistic': array([0.57263863], dtype=float32),
#   'probabilities': array([0.42736134, 0.5726386 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.4684743], dtype=float32),
#   'logistic': array([0.18717465], dtype=float32),
#   'probabilities': array([0.8128254 , 0.18717463], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.5780548], dtype=float32),
#   'logistic': array([0.35938033], dtype=float32),
#   'probabilities': array([0.6406197, 0.3593803], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.42732984], dtype=float32),
#   'logistic': array([0.39476413], dtype=float32),
#   'probabilities': array([0.6052359 , 0.39476413], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8564004], dtype=float32),
#   'logistic': array([0.13512313], dtype=float32),
#   'probabilities': array([0.8648768 , 0.13512318], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.5631535], dtype=float32),
#   'logistic': array([0.36281812], dtype=float32),
#   'probabilities': array([0.6371819, 0.3628181], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6885629], dtype=float32),
#   'logistic': array([0.15596493], dtype=float32),
#   'probabilities': array([0.8440351 , 0.15596493], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2244864], dtype=float32),
#   'logistic': array([0.2271479], dtype=float32),
#   'probabilities': array([0.7728521, 0.2271479], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.8308895], dtype=float32),
#   'logistic': array([0.30345702], dtype=float32),
#   'probabilities': array([0.696543  , 0.30345702], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.60813284], dtype=float32),
#   'logistic': array([0.64751476], dtype=float32),
#   'probabilities': array([0.35248524, 0.64751476], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.204885], dtype=float32),
#   'logistic': array([0.23060733], dtype=float32),
#   'probabilities': array([0.76939267, 0.23060735], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4383433], dtype=float32),
#   'logistic': array([0.19180202], dtype=float32),
#   'probabilities': array([0.8081979 , 0.19180201], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.251177], dtype=float32),
#   'logistic': array([0.77750355], dtype=float32),
#   'probabilities': array([0.22249646, 0.7775035 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.4885695], dtype=float32),
#   'logistic': array([0.18413654], dtype=float32),
#   'probabilities': array([0.8158635 , 0.18413654], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.6997396], dtype=float32),
#   'logistic': array([0.33186996], dtype=float32),
#   'probabilities': array([0.66813004, 0.33187   ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.074819], dtype=float32),
#   'logistic': array([0.11156847], dtype=float32),
#   'probabilities': array([0.88843155, 0.11156848], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.33281088], dtype=float32),
#   'logistic': array([0.5824431], dtype=float32),
#   'probabilities': array([0.41755682, 0.5824431 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.7728558], dtype=float32),
#   'logistic': array([0.9411913], dtype=float32),
#   'probabilities': array([0.05880874, 0.94119126], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.32427585], dtype=float32),
#   'logistic': array([0.41963404], dtype=float32),
#   'probabilities': array([0.58036596, 0.41963404], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.6346624], dtype=float32),
#   'logistic': array([0.34645414], dtype=float32),
#   'probabilities': array([0.6535459, 0.3464541], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.19061935], dtype=float32),
#   'logistic': array([0.54751104], dtype=float32),
#   'probabilities': array([0.45248893, 0.54751104], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.0574766], dtype=float32),
#   'logistic': array([0.25779194], dtype=float32),
#   'probabilities': array([0.742208  , 0.25779194], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.48625857], dtype=float32),
#   'logistic': array([0.38077536], dtype=float32),
#   'probabilities': array([0.61922467, 0.38077533], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.00178158], dtype=float32),
#   'logistic': array([0.4995546], dtype=float32),
#   'probabilities': array([0.5004454 , 0.49955463], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.5228796], dtype=float32),
#   'logistic': array([0.62782085], dtype=float32),
#   'probabilities': array([0.37217915, 0.62782085], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.1740202], dtype=float32),
#   'logistic': array([0.7638709], dtype=float32),
#   'probabilities': array([0.23612909, 0.7638709 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.6652379], dtype=float32),
#   'logistic': array([0.33956397], dtype=float32),
#   'probabilities': array([0.66043603, 0.339564  ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4614966], dtype=float32),
#   'logistic': array([0.1882385], dtype=float32),
#   'probabilities': array([0.81176144, 0.18823852], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.20507216], dtype=float32),
#   'logistic': array([0.5510891], dtype=float32),
#   'probabilities': array([0.44891086, 0.5510891 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5980121], dtype=float32),
#   'logistic': array([0.16825965], dtype=float32),
#   'probabilities': array([0.8317404 , 0.16825964], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.12572765], dtype=float32),
#   'logistic': array([0.53139055], dtype=float32),
#   'probabilities': array([0.46860942, 0.53139055], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.7296035], dtype=float32),
#   'logistic': array([0.15063825], dtype=float32),
#   'probabilities': array([0.8493617, 0.1506383], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.907499], dtype=float32),
#   'logistic': array([0.12926206], dtype=float32),
#   'probabilities': array([0.8707379 , 0.12926209], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.42026913], dtype=float32),
#   'logistic': array([0.60354763], dtype=float32),
#   'probabilities': array([0.39645234, 0.60354763], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.4327455], dtype=float32),
#   'logistic': array([0.19267127], dtype=float32),
#   'probabilities': array([0.8073287 , 0.19267127], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3316146], dtype=float32),
#   'logistic': array([0.20889242], dtype=float32),
#   'probabilities': array([0.7911076 , 0.20889242], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8227019], dtype=float32),
#   'logistic': array([0.13910997], dtype=float32),
#   'probabilities': array([0.86089003, 0.13910998], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4336823], dtype=float32),
#   'logistic': array([0.19252557], dtype=float32),
#   'probabilities': array([0.80747443, 0.19252558], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0713903], dtype=float32),
#   'logistic': array([0.25513878], dtype=float32),
#   'probabilities': array([0.74486125, 0.25513878], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.95316255], dtype=float32),
#   'logistic': array([0.27824926], dtype=float32),
#   'probabilities': array([0.72175074, 0.27824923], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.5371217], dtype=float32),
#   'logistic': array([0.3688574], dtype=float32),
#   'probabilities': array([0.63114256, 0.36885738], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8523223], dtype=float32),
#   'logistic': array([0.13560042], dtype=float32),
#   'probabilities': array([0.86439955, 0.13560046], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1064577], dtype=float32),
#   'logistic': array([0.24853188], dtype=float32),
#   'probabilities': array([0.7514681 , 0.24853186], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.21278], dtype=float32),
#   'logistic': array([0.22920954], dtype=float32),
#   'probabilities': array([0.77079046, 0.22920953], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2310709], dtype=float32),
#   'logistic': array([0.22599405], dtype=float32),
#   'probabilities': array([0.7740059 , 0.22599404], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.07081985], dtype=float32),
#   'logistic': array([0.48230243], dtype=float32),
#   'probabilities': array([0.5176976 , 0.48230246], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5456513], dtype=float32),
#   'logistic': array([0.17571524], dtype=float32),
#   'probabilities': array([0.82428473, 0.17571524], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1554594], dtype=float32),
#   'logistic': array([0.23949331], dtype=float32),
#   'probabilities': array([0.7605067 , 0.23949331], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.58187723], dtype=float32),
#   'logistic': array([0.6414992], dtype=float32),
#   'probabilities': array([0.35850075, 0.6414993 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.5280889], dtype=float32),
#   'logistic': array([0.62903726], dtype=float32),
#   'probabilities': array([0.3709627 , 0.62903726], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.02094483], dtype=float32),
#   'logistic': array([0.505236], dtype=float32),
#   'probabilities': array([0.49476397, 0.505236  ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.45769775], dtype=float32),
#   'logistic': array([0.38753211], dtype=float32),
#   'probabilities': array([0.6124679 , 0.38753214], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.04639304], dtype=float32),
#   'logistic': array([0.48840383], dtype=float32),
#   'probabilities': array([0.5115962 , 0.48840386], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4030495], dtype=float32),
#   'logistic': array([0.19733265], dtype=float32),
#   'probabilities': array([0.8026673 , 0.19733265], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3602345], dtype=float32),
#   'logistic': array([0.20420223], dtype=float32),
#   'probabilities': array([0.79579777, 0.20420218], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6902847], dtype=float32),
#   'logistic': array([0.1557384], dtype=float32),
#   'probabilities': array([0.84426165, 0.1557384 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8342276], dtype=float32),
#   'logistic': array([0.13773541], dtype=float32),
#   'probabilities': array([0.8622646 , 0.13773543], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.49432588], dtype=float32),
#   'logistic': array([0.621125], dtype=float32),
#   'probabilities': array([0.378875 , 0.6211249], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.122256], dtype=float32),
#   'logistic': array([0.24559307], dtype=float32),
#   'probabilities': array([0.7544069 , 0.24559306], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.23703218], dtype=float32),
#   'logistic': array([0.44101787], dtype=float32),
#   'probabilities': array([0.55898213, 0.44101784], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.37273443], dtype=float32),
#   'logistic': array([0.5921196], dtype=float32),
#   'probabilities': array([0.40788046, 0.5921196 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.80301124], dtype=float32),
#   'logistic': array([0.30938178], dtype=float32),
#   'probabilities': array([0.6906182 , 0.30938175], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.50961244], dtype=float32),
#   'logistic': array([0.6247156], dtype=float32),
#   'probabilities': array([0.37528437, 0.6247156 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.8340946], dtype=float32),
#   'logistic': array([0.13775122], dtype=float32),
#   'probabilities': array([0.8622488, 0.1377512], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.4930328], dtype=float32),
#   'logistic': array([0.62082064], dtype=float32),
#   'probabilities': array([0.3791794 , 0.62082064], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.8630581], dtype=float32),
#   'logistic': array([0.134347], dtype=float32),
#   'probabilities': array([0.86565304, 0.134347  ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.21841395], dtype=float32),
#   'logistic': array([0.55438745], dtype=float32),
#   'probabilities': array([0.44561255, 0.55438745], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.58775896], dtype=float32),
#   'logistic': array([0.35714924], dtype=float32),
#   'probabilities': array([0.64285076, 0.3571492 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5600463], dtype=float32),
#   'logistic': array([0.17363998], dtype=float32),
#   'probabilities': array([0.8263599 , 0.17363998], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.23267066], dtype=float32),
#   'logistic': array([0.5579066], dtype=float32),
#   'probabilities': array([0.44209334, 0.5579067 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.42580855], dtype=float32),
#   'logistic': array([0.60487235], dtype=float32),
#   'probabilities': array([0.39512765, 0.60487235], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.24833143], dtype=float32),
#   'logistic': array([0.56176573], dtype=float32),
#   'probabilities': array([0.43823427, 0.5617658 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5382674], dtype=float32),
#   'logistic': array([0.17678729], dtype=float32),
#   'probabilities': array([0.8232127 , 0.17678729], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.49817407], dtype=float32),
#   'logistic': array([0.3779699], dtype=float32),
#   'probabilities': array([0.62203014, 0.37796986], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6387279], dtype=float32),
#   'logistic': array([0.16263822], dtype=float32),
#   'probabilities': array([0.83736175, 0.16263823], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.87867224], dtype=float32),
#   'logistic': array([0.706547], dtype=float32),
#   'probabilities': array([0.293453, 0.706547], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.4494692], dtype=float32),
#   'logistic': array([0.80991673], dtype=float32),
#   'probabilities': array([0.19008327, 0.80991673], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.5573776], dtype=float32),
#   'logistic': array([0.63584554], dtype=float32),
#   'probabilities': array([0.36415443, 0.63584554], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.2110393], dtype=float32),
#   'logistic': array([0.22951722], dtype=float32),
#   'probabilities': array([0.7704828 , 0.22951722], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.14643562], dtype=float32),
#   'logistic': array([0.4634564], dtype=float32),
#   'probabilities': array([0.5365436 , 0.46345636], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.44875723], dtype=float32),
#   'logistic': array([0.3896563], dtype=float32),
#   'probabilities': array([0.6103437 , 0.38965628], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.22845542], dtype=float32),
#   'logistic': array([0.44313326], dtype=float32),
#   'probabilities': array([0.5568667 , 0.44313323], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.5878647], dtype=float32),
#   'logistic': array([0.35712495], dtype=float32),
#   'probabilities': array([0.6428751 , 0.35712495], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.2547788], dtype=float32),
#   'logistic': array([0.43664762], dtype=float32),
#   'probabilities': array([0.5633524 , 0.43664762], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6189554], dtype=float32),
#   'logistic': array([0.16534898], dtype=float32),
#   'probabilities': array([0.834651  , 0.16534898], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.25298107], dtype=float32),
#   'logistic': array([0.5629101], dtype=float32),
#   'probabilities': array([0.43708986, 0.5629101 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.19786108], dtype=float32),
#   'logistic': array([0.54930454], dtype=float32),
#   'probabilities': array([0.45069548, 0.54930454], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.0020585], dtype=float32),
#   'logistic': array([0.26853693], dtype=float32),
#   'probabilities': array([0.73146313, 0.2685369 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4476253], dtype=float32),
#   'logistic': array([0.19036731], dtype=float32),
#   'probabilities': array([0.8096327 , 0.19036731], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5126331], dtype=float32),
#   'logistic': array([0.18054888], dtype=float32),
#   'probabilities': array([0.8194511, 0.1805489], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.85922664], dtype=float32),
#   'logistic': array([0.29750097], dtype=float32),
#   'probabilities': array([0.70249903, 0.29750094], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.51731837], dtype=float32),
#   'logistic': array([0.37347955], dtype=float32),
#   'probabilities': array([0.62652045, 0.37347946], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.757308], dtype=float32),
#   'logistic': array([0.14712778], dtype=float32),
#   'probabilities': array([0.8528722, 0.1471278], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.68209493], dtype=float32),
#   'logistic': array([0.3357939], dtype=float32),
#   'probabilities': array([0.6642061 , 0.33579388], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2025973], dtype=float32),
#   'logistic': array([0.2310135], dtype=float32),
#   'probabilities': array([0.7689865, 0.2310135], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.146474], dtype=float32),
#   'logistic': array([0.10466118], dtype=float32),
#   'probabilities': array([0.8953388 , 0.10466117], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.844893], dtype=float32),
#   'logistic': array([0.13647364], dtype=float32),
#   'probabilities': array([0.8635264 , 0.13647364], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.1003598], dtype=float32),
#   'logistic': array([0.75032747], dtype=float32),
#   'probabilities': array([0.24967249, 0.7503275 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.4731706], dtype=float32),
#   'logistic': array([0.18646118], dtype=float32),
#   'probabilities': array([0.81353885, 0.18646117], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8072517], dtype=float32),
#   'logistic': array([0.14097062], dtype=float32),
#   'probabilities': array([0.8590294 , 0.14097062], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.676131], dtype=float32),
#   'logistic': array([0.15760842], dtype=float32),
#   'probabilities': array([0.8423915 , 0.15760845], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.00688088], dtype=float32),
#   'logistic': array([0.49827978], dtype=float32),
#   'probabilities': array([0.5017202 , 0.49827975], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.18294632], dtype=float32),
#   'logistic': array([0.45439056], dtype=float32),
#   'probabilities': array([0.5456095, 0.4543906], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0885167], dtype=float32),
#   'logistic': array([0.2518977], dtype=float32),
#   'probabilities': array([0.7481023, 0.2518977], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.18220872], dtype=float32),
#   'logistic': array([0.45457345], dtype=float32),
#   'probabilities': array([0.54542655, 0.45457342], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3885627], dtype=float32),
#   'logistic': array([0.19963731], dtype=float32),
#   'probabilities': array([0.8003627 , 0.19963732], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0669199], dtype=float32),
#   'logistic': array([0.25598925], dtype=float32),
#   'probabilities': array([0.74401075, 0.25598928], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.1749376], dtype=float32),
#   'logistic': array([0.5436232], dtype=float32),
#   'probabilities': array([0.45637682, 0.5436232 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.05476952], dtype=float32),
#   'logistic': array([0.48631105], dtype=float32),
#   'probabilities': array([0.513689  , 0.48631105], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7498657], dtype=float32),
#   'logistic': array([0.14806417], dtype=float32),
#   'probabilities': array([0.85193586, 0.14806415], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.4521479], dtype=float32),
#   'logistic': array([0.3888502], dtype=float32),
#   'probabilities': array([0.6111498 , 0.38885018], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.7288953], dtype=float32),
#   'logistic': array([0.6745628], dtype=float32),
#   'probabilities': array([0.3254372, 0.6745628], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.14241421], dtype=float32),
#   'logistic': array([0.5355435], dtype=float32),
#   'probabilities': array([0.4644565, 0.5355435], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.47625864], dtype=float32),
#   'logistic': array([0.38313597], dtype=float32),
#   'probabilities': array([0.616864  , 0.38313597], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.31287682], dtype=float32),
#   'logistic': array([0.5775873], dtype=float32),
#   'probabilities': array([0.4224127, 0.5775873], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.2629846], dtype=float32),
#   'logistic': array([0.22046053], dtype=float32),
#   'probabilities': array([0.77953947, 0.22046053], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.351022], dtype=float32),
#   'logistic': array([0.20570333], dtype=float32),
#   'probabilities': array([0.7942966 , 0.20570332], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7794762], dtype=float32),
#   'logistic': array([0.14436781], dtype=float32),
#   'probabilities': array([0.85563225, 0.14436784], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9074508], dtype=float32),
#   'logistic': array([0.28752178], dtype=float32),
#   'probabilities': array([0.7124783 , 0.28752178], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.00631738], dtype=float32),
#   'logistic': array([0.50157934], dtype=float32),
#   'probabilities': array([0.49842066, 0.50157934], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.75547767], dtype=float32),
#   'logistic': array([0.68037105], dtype=float32),
#   'probabilities': array([0.31962892, 0.6803711 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.144175], dtype=float32),
#   'logistic': array([0.24155465], dtype=float32),
#   'probabilities': array([0.7584453 , 0.24155463], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5456866], dtype=float32),
#   'logistic': array([0.17571011], dtype=float32),
#   'probabilities': array([0.82428986, 0.17571013], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.30595422], dtype=float32),
#   'logistic': array([0.42410257], dtype=float32),
#   'probabilities': array([0.5758974 , 0.42410254], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1588113], dtype=float32),
#   'logistic': array([0.23888335], dtype=float32),
#   'probabilities': array([0.7611167 , 0.23888336], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7117109], dtype=float32),
#   'logistic': array([0.15294193], dtype=float32),
#   'probabilities': array([0.84705806, 0.15294193], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3828661], dtype=float32),
#   'logistic': array([0.20054907], dtype=float32),
#   'probabilities': array([0.79945093, 0.20054908], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8416222], dtype=float32),
#   'logistic': array([0.13685954], dtype=float32),
#   'probabilities': array([0.8631404 , 0.13685954], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.32504845], dtype=float32),
#   'logistic': array([0.4194459], dtype=float32),
#   'probabilities': array([0.5805541, 0.4194459], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.2020186], dtype=float32),
#   'logistic': array([0.7688837], dtype=float32),
#   'probabilities': array([0.23111631, 0.7688837 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.2033426], dtype=float32),
#   'logistic': array([0.7691189], dtype=float32),
#   'probabilities': array([0.23088112, 0.76911885], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.14080906], dtype=float32),
#   'logistic': array([0.5351442], dtype=float32),
#   'probabilities': array([0.46485576, 0.5351442 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.00915682], dtype=float32),
#   'logistic': array([0.5022892], dtype=float32),
#   'probabilities': array([0.4977108, 0.5022892], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.31247735], dtype=float32),
#   'logistic': array([0.57748985], dtype=float32),
#   'probabilities': array([0.42251015, 0.57748985], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.9755049], dtype=float32),
#   'logistic': array([0.12179884], dtype=float32),
#   'probabilities': array([0.8782011 , 0.12179884], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.13284421], dtype=float32),
#   'logistic': array([0.5331623], dtype=float32),
#   'probabilities': array([0.4668377, 0.5331623], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.200471], dtype=float32),
#   'logistic': array([0.76860857], dtype=float32),
#   'probabilities': array([0.23139143, 0.76860857], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.33709413], dtype=float32),
#   'logistic': array([0.41651553], dtype=float32),
#   'probabilities': array([0.5834845, 0.4165155], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9257289], dtype=float32),
#   'logistic': array([0.28379205], dtype=float32),
#   'probabilities': array([0.716208  , 0.28379202], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.667226], dtype=float32),
#   'logistic': array([0.33911824], dtype=float32),
#   'probabilities': array([0.66088176, 0.33911827], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.36822712], dtype=float32),
#   'logistic': array([0.5910305], dtype=float32),
#   'probabilities': array([0.4089695 , 0.59103054], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.1454492], dtype=float32),
#   'logistic': array([0.2413213], dtype=float32),
#   'probabilities': array([0.7586787 , 0.24132128], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.62496233], dtype=float32),
#   'logistic': array([0.6513463], dtype=float32),
#   'probabilities': array([0.34865367, 0.65134627], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.33121002], dtype=float32),
#   'logistic': array([0.41794625], dtype=float32),
#   'probabilities': array([0.5820538 , 0.41794625], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.3394773], dtype=float32),
#   'logistic': array([0.41593647], dtype=float32),
#   'probabilities': array([0.58406353, 0.41593644], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5923564], dtype=float32),
#   'logistic': array([0.16905262], dtype=float32),
#   'probabilities': array([0.83094734, 0.16905262], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3374025], dtype=float32),
#   'logistic': array([0.20793754], dtype=float32),
#   'probabilities': array([0.7920624 , 0.20793754], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4118624], dtype=float32),
#   'logistic': array([0.19594046], dtype=float32),
#   'probabilities': array([0.8040595 , 0.19594046], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.26567245], dtype=float32),
#   'logistic': array([0.43396983], dtype=float32),
#   'probabilities': array([0.5660302, 0.4339698], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6720773], dtype=float32),
#   'logistic': array([0.1581474], dtype=float32),
#   'probabilities': array([0.8418526 , 0.15814742], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.005911], dtype=float32),
#   'logistic': array([0.73221916], dtype=float32),
#   'probabilities': array([0.26778084, 0.73221916], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.3577939], dtype=float32),
#   'logistic': array([0.20459908], dtype=float32),
#   'probabilities': array([0.7954009 , 0.20459907], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.03057539], dtype=float32),
#   'logistic': array([0.5076432], dtype=float32),
#   'probabilities': array([0.49235678, 0.5076433 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.6366625], dtype=float32),
#   'logistic': array([0.16291973], dtype=float32),
#   'probabilities': array([0.83708036, 0.16291973], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.74576616], dtype=float32),
#   'logistic': array([0.67825544], dtype=float32),
#   'probabilities': array([0.32174453, 0.67825544], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.82651067], dtype=float32),
#   'logistic': array([0.30438337], dtype=float32),
#   'probabilities': array([0.69561666, 0.3043834 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3155024], dtype=float32),
#   'logistic': array([0.21156757], dtype=float32),
#   'probabilities': array([0.7884324 , 0.21156755], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.68126583], dtype=float32),
#   'logistic': array([0.33597884], dtype=float32),
#   'probabilities': array([0.6640212 , 0.33597884], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.6157735], dtype=float32),
#   'logistic': array([0.35074332], dtype=float32),
#   'probabilities': array([0.6492567 , 0.35074332], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4796137], dtype=float32),
#   'logistic': array([0.18548578], dtype=float32),
#   'probabilities': array([0.8145142 , 0.18548578], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.8984932], dtype=float32),
#   'logistic': array([0.7106397], dtype=float32),
#   'probabilities': array([0.28936026, 0.7106398 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.2689226], dtype=float32),
#   'logistic': array([0.21944174], dtype=float32),
#   'probabilities': array([0.7805582 , 0.21944174], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4352139], dtype=float32),
#   'logistic': array([0.1922876], dtype=float32),
#   'probabilities': array([0.80771244, 0.1922876 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0050523], dtype=float32),
#   'logistic': array([0.26794928], dtype=float32),
#   'probabilities': array([0.7320508 , 0.26794922], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.22327566], dtype=float32),
#   'logistic': array([0.44441184], dtype=float32),
#   'probabilities': array([0.5555882 , 0.44441184], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0408177], dtype=float32),
#   'logistic': array([0.26099223], dtype=float32),
#   'probabilities': array([0.7390078 , 0.26099226], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9147758], dtype=float32),
#   'logistic': array([0.12844527], dtype=float32),
#   'probabilities': array([0.87155473, 0.12844527], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.6028823], dtype=float32),
#   'logistic': array([0.8324208], dtype=float32),
#   'probabilities': array([0.16757917, 0.8324209 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.71341634], dtype=float32),
#   'logistic': array([0.6711556], dtype=float32),
#   'probabilities': array([0.32884437, 0.6711556 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.08750737], dtype=float32),
#   'logistic': array([0.52186286], dtype=float32),
#   'probabilities': array([0.47813714, 0.5218629 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.97939575], dtype=float32),
#   'logistic': array([0.7269883], dtype=float32),
#   'probabilities': array([0.27301168, 0.72698826], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.8695455], dtype=float32),
#   'logistic': array([0.1335943], dtype=float32),
#   'probabilities': array([0.86640567, 0.13359432], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.728662], dtype=float32),
#   'logistic': array([0.1507588], dtype=float32),
#   'probabilities': array([0.84924114, 0.1507588 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2381924], dtype=float32),
#   'logistic': array([0.22475079], dtype=float32),
#   'probabilities': array([0.7752492 , 0.22475077], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.63056123], dtype=float32),
#   'logistic': array([0.34738332], dtype=float32),
#   'probabilities': array([0.65261674, 0.3473833 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.466246], dtype=float32),
#   'logistic': array([0.38550514], dtype=float32),
#   'probabilities': array([0.61449486, 0.38550517], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.21141386], dtype=float32),
#   'logistic': array([0.5526575], dtype=float32),
#   'probabilities': array([0.44734251, 0.5526575 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.26268518], dtype=float32),
#   'logistic': array([0.56529623], dtype=float32),
#   'probabilities': array([0.43470374, 0.56529623], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.4387008], dtype=float32),
#   'logistic': array([0.3920506], dtype=float32),
#   'probabilities': array([0.60794944, 0.3920506 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.5851294], dtype=float32),
#   'logistic': array([0.3577532], dtype=float32),
#   'probabilities': array([0.64224684, 0.3577532 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.58803374], dtype=float32),
#   'logistic': array([0.35708615], dtype=float32),
#   'probabilities': array([0.6429139 , 0.35708615], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3786759], dtype=float32),
#   'logistic': array([0.20122173], dtype=float32),
#   'probabilities': array([0.7987783 , 0.20122173], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.48446035], dtype=float32),
#   'logistic': array([0.6188006], dtype=float32),
#   'probabilities': array([0.38119945, 0.6188006 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.8262601], dtype=float32),
#   'logistic': array([0.13868439], dtype=float32),
#   'probabilities': array([0.86131567, 0.1386844 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1397489], dtype=float32),
#   'logistic': array([0.24236646], dtype=float32),
#   'probabilities': array([0.75763357, 0.24236646], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.19916153], dtype=float32),
#   'logistic': array([0.54962647], dtype=float32),
#   'probabilities': array([0.45037356, 0.54962647], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.5678253], dtype=float32),
#   'logistic': array([0.36173877], dtype=float32),
#   'probabilities': array([0.63826126, 0.36173877], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3167695], dtype=float32),
#   'logistic': array([0.21135625], dtype=float32),
#   'probabilities': array([0.7886438 , 0.21135628], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.8796587], dtype=float32),
#   'logistic': array([0.29324853], dtype=float32),
#   'probabilities': array([0.70675147, 0.2932485 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.003723], dtype=float32),
#   'logistic': array([0.2682101], dtype=float32),
#   'probabilities': array([0.73178995, 0.26821005], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7714838], dtype=float32),
#   'logistic': array([0.14535788], dtype=float32),
#   'probabilities': array([0.8546421, 0.1453579], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3025216], dtype=float32),
#   'logistic': array([0.21374092], dtype=float32),
#   'probabilities': array([0.78625906, 0.21374096], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.22566772], dtype=float32),
#   'logistic': array([0.5561787], dtype=float32),
#   'probabilities': array([0.4438213 , 0.55617875], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.80068123], dtype=float32),
#   'logistic': array([0.6901202], dtype=float32),
#   'probabilities': array([0.3098798 , 0.69012016], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.57271564], dtype=float32),
#   'logistic': array([0.6393895], dtype=float32),
#   'probabilities': array([0.36061046, 0.6393896 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.82477117], dtype=float32),
#   'logistic': array([0.6952482], dtype=float32),
#   'probabilities': array([0.3047518, 0.6952482], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.18432951], dtype=float32),
#   'logistic': array([0.45404762], dtype=float32),
#   'probabilities': array([0.5459523 , 0.45404765], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.868186], dtype=float32),
#   'logistic': array([0.29563195], dtype=float32),
#   'probabilities': array([0.7043681 , 0.29563192], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.04676676], dtype=float32),
#   'logistic': array([0.51168954], dtype=float32),
#   'probabilities': array([0.48831043, 0.51168954], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.4243428], dtype=float32),
#   'logistic': array([0.1939817], dtype=float32),
#   'probabilities': array([0.8060183 , 0.19398166], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6109991], dtype=float32),
#   'logistic': array([0.16644996], dtype=float32),
#   'probabilities': array([0.8335501 , 0.16644995], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4271848], dtype=float32),
#   'logistic': array([0.19353771], dtype=float32),
#   'probabilities': array([0.8064623, 0.1935377], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.03388524], dtype=float32),
#   'logistic': array([0.4915295], dtype=float32),
#   'probabilities': array([0.5084705 , 0.49152946], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.7640774], dtype=float32),
#   'logistic': array([0.05929649], dtype=float32),
#   'probabilities': array([0.9407035 , 0.05929652], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.94146925], dtype=float32),
#   'logistic': array([0.28060365], dtype=float32),
#   'probabilities': array([0.71939635, 0.28060365], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4572612], dtype=float32),
#   'logistic': array([0.18888658], dtype=float32),
#   'probabilities': array([0.8111134 , 0.18888657], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0179517], dtype=float32),
#   'logistic': array([0.26542658], dtype=float32),
#   'probabilities': array([0.7345734 , 0.26542658], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0795838], dtype=float32),
#   'logistic': array([0.2535848], dtype=float32),
#   'probabilities': array([0.7464152, 0.2535848], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.87688494], dtype=float32),
#   'logistic': array([0.29382372], dtype=float32),
#   'probabilities': array([0.7061763, 0.2938237], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.2085711], dtype=float32),
#   'logistic': array([0.770046], dtype=float32),
#   'probabilities': array([0.22995397, 0.770046  ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.4420413], dtype=float32),
#   'logistic': array([0.19122946], dtype=float32),
#   'probabilities': array([0.8087706 , 0.19122946], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8828723], dtype=float32),
#   'logistic': array([0.13205928], dtype=float32),
#   'probabilities': array([0.8679407, 0.1320593], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.3649403], dtype=float32),
#   'logistic': array([0.5902358], dtype=float32),
#   'probabilities': array([0.40976417, 0.59023577], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.03005588], dtype=float32),
#   'logistic': array([0.4924866], dtype=float32),
#   'probabilities': array([0.5075134, 0.4924866], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.7229928], dtype=float32),
#   'logistic': array([0.84851396], dtype=float32),
#   'probabilities': array([0.15148608, 0.8485139 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.62545407], dtype=float32),
#   'logistic': array([0.65145797], dtype=float32),
#   'probabilities': array([0.34854203, 0.65145797], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.8408444], dtype=float32),
#   'logistic': array([0.13695146], dtype=float32),
#   'probabilities': array([0.8630485 , 0.13695145], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.5607103], dtype=float32),
#   'logistic': array([0.6366169], dtype=float32),
#   'probabilities': array([0.3633831, 0.6366169], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)}]

# %% [markdown]
# # DNN Classifier

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10, 10, 10], 
                                       feature_columns=feat_cols, 
                                       n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/j8/4vht5fhd3rg9wv8rx18tt20c0000gp/T/tmpmgsqxwjb
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/j8/4vht5fhd3rg9wv8rx18tt20c0000gp/T/tmpmgsqxwjb', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x13a0b47f0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn=input_func, steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-391751ec2827> in <module>
# ----> 1 dnn_model.train(input_fn=input_func, steps=1000)
#
# ~/anaconda3/envs/tfdl/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     356
#     357       saving_listeners = _check_listeners_type(saving_listeners)
# --> 358       loss = self._train_model(input_fn, hooks, saving_listeners)
#     359       logging.info('Loss for final step: %s.', loss)
#     360       return self
#
# ~/anaconda3/envs/tfdl/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1122       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1123     else:
# -> 1124       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1125
#    1126   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# ~/anaconda3/envs/tfdl/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1152       worker_hooks.extend(input_hooks)
#    1153       estimator_spec = self._call_model_fn(
# -> 1154           features, labels, model_fn_lib.ModeKeys.TRAIN, self.config)
#    1155       global_step_tensor = training_util.get_global_step(g)
#    1156       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#
# ~/anaconda3/envs/tfdl/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/estimator.py in _call_model_fn(self, features, labels, mode, config)
#    1110
#    1111     logging.info('Calling model_fn.')
# -> 1112     model_fn_results = self._model_fn(features=features, **kwargs)
#    1113     logging.info('Done calling model_fn.')
#    1114
#
# ~/anaconda3/envs/tfdl/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/canned/dnn.py in _model_fn(features, labels, mode, config)
#     520           input_layer_partitioner=input_layer_partitioner,
#     521           config=config,
# --> 522           batch_norm=batch_norm)
#     523
#     524     super(DNNClassifier, self).__init__(
#
# ~/anaconda3/envs/tfdl/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/canned/dnn.py in _dnn_model_fn(features, labels, mode, head, hidden_units, feature_columns, optimizer, activation_fn, dropout, input_layer_partitioner, config, use_tpu, batch_norm)
#     285         input_layer_partitioner=input_layer_partitioner,
#     286         batch_norm=batch_norm)
# --> 287     logits = logit_fn(features=features, mode=mode)
#     288
#     289     if use_tpu:
#
# ~/anaconda3/envs/tfdl/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/canned/dnn.py in dnn_logit_fn(features, mode)
#     100         input_layer_partitioner,
#     101         batch_norm,
# --> 102         name='dnn')
#     103     return dnn_model(features, mode)
#     104
#
# ~/anaconda3/envs/tfdl/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/canned/dnn.py in __init__(self, units, hidden_units, feature_columns, activation_fn, dropout, input_layer_partitioner, batch_norm, name, **kwargs)
#     127     if feature_column_lib.is_feature_column_v2(feature_columns):
#     128       self._input_layer = feature_column_lib.DenseFeatures(
# --> 129           feature_columns=feature_columns, name='input_layer')
#     130     else:
#     131       self._input_layer = feature_column.InputLayer(
#
# ~/anaconda3/envs/tfdl/lib/python3.7/site-packages/tensorflow/python/feature_column/feature_column_v2.py in __init__(self, feature_columns, trainable, name, **kwargs)
#     364             'Items of feature_columns must be a DenseColumn. '
#     365             'You can wrap a categorical column with an '
# --> 366             'embedding_column or indicator_column. Given: {}'.format(column))
#     367
#     368   @property
#
# ValueError: Items of feature_columns must be a DenseColumn. You can wrap a categorical column with an embedding_column or indicator_column. Given: VocabularyListCategoricalColumn(key='Group', vocabulary_list=('A', 'B', 'C', 'D'), dtype=tf.string, default_value=-1, num_oov_buckets=0)

# %%
embedded_group_col = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
feat_cols = [num_preg, 
             plasma_gluc, 
             dias_press, 
             tricep, 
             insulin, 
             bmi, 
             diabetes_pedigree, 
             embedded_group_col, 
             age_bucket]

# %%
feat_cols
# Out:
# [NumericColumn(key='Number_pregnant', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='Glucose_concentration', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='Blood_pressure', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='Triceps', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='Insulin', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='BMI', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='Pedigree', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  EmbeddingColumn(categorical_column=VocabularyListCategoricalColumn(key='Group', vocabulary_list=('A', 'B', 'C', 'D'), dtype=tf.string, default_value=-1, num_oov_buckets=0), dimension=4, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x13aaa91d0>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True),
#  BucketizedColumn(source_column=NumericColumn(key='Age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(20, 30, 40, 50, 60, 70, 80))]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train, 
                                                 y=y_train,
                                                 batch_size=10,
                                                 num_epochs=1000,
                                                 shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10, 20, 10], 
                                       feature_columns=feat_cols, 
                                       n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/j8/4vht5fhd3rg9wv8rx18tt20c0000gp/T/tmp7q15ipmk
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/j8/4vht5fhd3rg9wv8rx18tt20c0000gp/T/tmp7q15ipmk', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x140dd9c88>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn=input_func, steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/j8/4vht5fhd3rg9wv8rx18tt20c0000gp/T/tmp7q15ipmk/model.ckpt.
# INFO:tensorflow:loss = 6.9249144, step = 1
# INFO:tensorflow:global_step/sec: 38.9996
# INFO:tensorflow:loss = 6.078274, step = 101 (2.574 sec)
# INFO:tensorflow:global_step/sec: 96.4353
# INFO:tensorflow:loss = 5.1433935, step = 201 (1.037 sec)
# INFO:tensorflow:global_step/sec: 120.829
# INFO:tensorflow:loss = 5.088038, step = 301 (0.822 sec)
# INFO:tensorflow:global_step/sec: 121.694
# INFO:tensorflow:loss = 4.2497087, step = 401 (0.820 sec)
# INFO:tensorflow:global_step/sec: 97.6386
# INFO:tensorflow:loss = 3.757228, step = 501 (1.026 sec)
# INFO:tensorflow:global_step/sec: 118.23
# INFO:tensorflow:loss = 4.3033667, step = 601 (0.845 sec)
# INFO:tensorflow:global_step/sec: 77.7996
# INFO:tensorflow:loss = 4.8111277, step = 701 (1.291 sec)
# INFO:tensorflow:global_step/sec: 85.0146
# INFO:tensorflow:loss = 1.3373481, step = 801 (1.179 sec)
# INFO:tensorflow:global_step/sec: 85.9465
# INFO:tensorflow:loss = 7.378957, step = 901 (1.154 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/j8/4vht5fhd3rg9wv8rx18tt20c0000gp/T/tmp7q15ipmk/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.5517886.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test, 
                                                     y=y_test, 
                                                     batch_size=10, 
                                                     num_epochs=1, 
                                                     shuffle=False)

# %%
dnn_model.evaluate(input_fn=eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-06T02:17:38Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/j8/4vht5fhd3rg9wv8rx18tt20c0000gp/T/tmp7q15ipmk/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-06-06-02:17:43
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.7619048, accuracy_baseline = 0.64935064, auc = 0.84168726, auc_precision_recall = 0.7506414, average_loss = 0.47220004, global_step = 1000, label/mean = 0.35064936, loss = 4.544925, precision = 0.63829786, prediction/mean = 0.391857, recall = 0.7407407
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /var/folders/j8/4vht5fhd3rg9wv8rx18tt20c0000gp/T/tmp7q15ipmk/model.ckpt-1000
# {'accuracy': 0.7619048,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.84168726,
#  'auc_precision_recall': 0.7506414,
#  'average_loss': 0.47220004,
#  'label/mean': 0.35064936,
#  'loss': 4.544925,
#  'precision': 0.63829786,
#  'prediction/mean': 0.391857,
#  'recall': 0.7407407,
#  'global_step': 1000}

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
# Predictions is a generator! 
predictions = dnn_model.predict(pred_input_func)

# %%
list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/j8/4vht5fhd3rg9wv8rx18tt20c0000gp/T/tmp7q15ipmk/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'logits': array([-0.11971052], dtype=float32),
#   'logistic': array([0.47010806], dtype=float32),
#   'probabilities': array([0.52989197, 0.4701081 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.6707118], dtype=float32),
#   'logistic': array([0.8416707], dtype=float32),
#   'probabilities': array([0.15832931, 0.8416707 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.2099702], dtype=float32),
#   'logistic': array([0.22970629], dtype=float32),
#   'probabilities': array([0.7702937 , 0.22970632], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.11737108], dtype=float32),
#   'logistic': array([0.47069088], dtype=float32),
#   'probabilities': array([0.52930915, 0.4706909 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.4142942], dtype=float32),
#   'logistic': array([0.08208916], dtype=float32),
#   'probabilities': array([0.9179108 , 0.08208916], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([2.8525488], dtype=float32),
#   'logistic': array([0.9454503], dtype=float32),
#   'probabilities': array([0.05454972, 0.9454503 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.560236], dtype=float32),
#   'logistic': array([0.8263872], dtype=float32),
#   'probabilities': array([0.17361279, 0.8263872 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.9778211], dtype=float32),
#   'logistic': array([0.12155125], dtype=float32),
#   'probabilities': array([0.8784487 , 0.12155131], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.50588757], dtype=float32),
#   'logistic': array([0.3761581], dtype=float32),
#   'probabilities': array([0.62384194, 0.3761581 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9304674], dtype=float32),
#   'logistic': array([0.12669887], dtype=float32),
#   'probabilities': array([0.8733012 , 0.12669887], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-3.824923], dtype=float32),
#   'logistic': array([0.02135414], dtype=float32),
#   'probabilities': array([0.97864586, 0.02135416], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.3119848], dtype=float32),
#   'logistic': array([0.09013519], dtype=float32),
#   'probabilities': array([0.9098647 , 0.09013523], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.5925152], dtype=float32),
#   'logistic': array([0.356058], dtype=float32),
#   'probabilities': array([0.643942  , 0.35605794], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.30911773], dtype=float32),
#   'logistic': array([0.5766699], dtype=float32),
#   'probabilities': array([0.42333007, 0.5766699 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.3538945], dtype=float32),
#   'logistic': array([0.20523438], dtype=float32),
#   'probabilities': array([0.7947656 , 0.20523441], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.5994403], dtype=float32),
#   'logistic': array([0.8319402], dtype=float32),
#   'probabilities': array([0.16805984, 0.8319401 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.9517444], dtype=float32),
#   'logistic': array([0.7214658], dtype=float32),
#   'probabilities': array([0.27853414, 0.7214658 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-3.35531], dtype=float32),
#   'logistic': array([0.03372175], dtype=float32),
#   'probabilities': array([0.9662783 , 0.03372171], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.2692583], dtype=float32),
#   'logistic': array([0.5669108], dtype=float32),
#   'probabilities': array([0.4330892, 0.5669108], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-3.015219], dtype=float32),
#   'logistic': array([0.04674305], dtype=float32),
#   'probabilities': array([0.95325696, 0.04674305], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3216631], dtype=float32),
#   'logistic': array([0.21054173], dtype=float32),
#   'probabilities': array([0.7894582 , 0.21054171], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.12093192], dtype=float32),
#   'logistic': array([0.5301962], dtype=float32),
#   'probabilities': array([0.4698038, 0.5301962], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.71580833], dtype=float32),
#   'logistic': array([0.6716833], dtype=float32),
#   'probabilities': array([0.32831666, 0.6716833 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.38519573], dtype=float32),
#   'logistic': array([0.40487438], dtype=float32),
#   'probabilities': array([0.5951257 , 0.40487438], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1639264], dtype=float32),
#   'logistic': array([0.23795459], dtype=float32),
#   'probabilities': array([0.7620454 , 0.23795457], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.4817698], dtype=float32),
#   'logistic': array([0.8148397], dtype=float32),
#   'probabilities': array([0.18516023, 0.8148397 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.1425796], dtype=float32),
#   'logistic': array([0.10502666], dtype=float32),
#   'probabilities': array([0.8949733 , 0.10502666], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.8955975], dtype=float32),
#   'logistic': array([0.7100439], dtype=float32),
#   'probabilities': array([0.28995603, 0.7100439 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-4.5017285], dtype=float32),
#   'logistic': array([0.01096818], dtype=float32),
#   'probabilities': array([0.98903185, 0.01096818], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.2599355], dtype=float32),
#   'logistic': array([0.56462044], dtype=float32),
#   'probabilities': array([0.43537953, 0.56462044], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.5545361], dtype=float32),
#   'logistic': array([0.82556796], dtype=float32),
#   'probabilities': array([0.17443208, 0.8255679 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.0067476], dtype=float32),
#   'logistic': array([0.4983131], dtype=float32),
#   'probabilities': array([0.5016869 , 0.49831307], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.1272242], dtype=float32),
#   'logistic': array([0.46823677], dtype=float32),
#   'probabilities': array([0.5317632 , 0.46823677], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.5201406], dtype=float32),
#   'logistic': array([0.62718064], dtype=float32),
#   'probabilities': array([0.37281936, 0.6271807 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.58582413], dtype=float32),
#   'logistic': array([0.3575936], dtype=float32),
#   'probabilities': array([0.6424064 , 0.35759357], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5389433], dtype=float32),
#   'logistic': array([0.17668891], dtype=float32),
#   'probabilities': array([0.8233111 , 0.17668895], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.5650685], dtype=float32),
#   'logistic': array([0.63762444], dtype=float32),
#   'probabilities': array([0.36237553, 0.6376245 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.6505255], dtype=float32),
#   'logistic': array([0.6571289], dtype=float32),
#   'probabilities': array([0.34287113, 0.65712893], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.5711339], dtype=float32),
#   'logistic': array([0.8279452], dtype=float32),
#   'probabilities': array([0.1720548, 0.8279452], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.3880327], dtype=float32),
#   'logistic': array([0.08408982], dtype=float32),
#   'probabilities': array([0.9159102 , 0.08408983], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.2415445], dtype=float32),
#   'logistic': array([0.09608129], dtype=float32),
#   'probabilities': array([0.90391874, 0.09608132], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.33040118], dtype=float32),
#   'logistic': array([0.41814303], dtype=float32),
#   'probabilities': array([0.581857  , 0.41814303], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.2825415], dtype=float32),
#   'logistic': array([0.09257922], dtype=float32),
#   'probabilities': array([0.9074208 , 0.09257922], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.4256304], dtype=float32),
#   'logistic': array([0.6048297], dtype=float32),
#   'probabilities': array([0.39517027, 0.6048298 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-3.0256789], dtype=float32),
#   'logistic': array([0.04627919], dtype=float32),
#   'probabilities': array([0.9537208 , 0.04627918], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-3.7473426], dtype=float32),
#   'logistic': array([0.02303714], dtype=float32),
#   'probabilities': array([0.9769629, 0.0230371], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.65780216], dtype=float32),
#   'logistic': array([0.6587665], dtype=float32),
#   'probabilities': array([0.34123352, 0.6587665 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.9247133], dtype=float32),
#   'logistic': array([0.2839985], dtype=float32),
#   'probabilities': array([0.7160015, 0.2839985], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.05442387], dtype=float32),
#   'logistic': array([0.4863974], dtype=float32),
#   'probabilities': array([0.5136026, 0.4863974], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-4.560141], dtype=float32),
#   'logistic': array([0.01035229], dtype=float32),
#   'probabilities': array([0.9896477 , 0.01035229], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8064446], dtype=float32),
#   'logistic': array([0.14106834], dtype=float32),
#   'probabilities': array([0.8589316 , 0.14106837], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5922186], dtype=float32),
#   'logistic': array([0.16907197], dtype=float32),
#   'probabilities': array([0.830928  , 0.16907197], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3863726], dtype=float32),
#   'logistic': array([0.1999875], dtype=float32),
#   'probabilities': array([0.8000125 , 0.19998749], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.81021863], dtype=float32),
#   'logistic': array([0.30784392], dtype=float32),
#   'probabilities': array([0.6921561 , 0.30784392], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.6673784], dtype=float32),
#   'logistic': array([0.06492591], dtype=float32),
#   'probabilities': array([0.93507403, 0.06492594], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.857401], dtype=float32),
#   'logistic': array([0.29788268], dtype=float32),
#   'probabilities': array([0.7021174 , 0.29788265], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1593786], dtype=float32),
#   'logistic': array([0.23878023], dtype=float32),
#   'probabilities': array([0.7612198 , 0.23878022], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2758977], dtype=float32),
#   'logistic': array([0.21824929], dtype=float32),
#   'probabilities': array([0.7817506 , 0.21824932], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.5123188], dtype=float32),
#   'logistic': array([0.6253499], dtype=float32),
#   'probabilities': array([0.3746501, 0.6253499], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.536819], dtype=float32),
#   'logistic': array([0.07331701], dtype=float32),
#   'probabilities': array([0.926683  , 0.07331701], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.1172223], dtype=float32),
#   'logistic': array([0.10743412], dtype=float32),
#   'probabilities': array([0.89256585, 0.10743413], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.72034127], dtype=float32),
#   'logistic': array([0.67268217], dtype=float32),
#   'probabilities': array([0.32731783, 0.67268217], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.6656497], dtype=float32),
#   'logistic': array([0.84099495], dtype=float32),
#   'probabilities': array([0.15900505, 0.8409949 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.7909146], dtype=float32),
#   'logistic': array([0.31197232], dtype=float32),
#   'probabilities': array([0.6880277 , 0.31197232], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.08715609], dtype=float32),
#   'logistic': array([0.52177525], dtype=float32),
#   'probabilities': array([0.47822475, 0.52177525], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.2363706], dtype=float32),
#   'logistic': array([0.7749316], dtype=float32),
#   'probabilities': array([0.22506838, 0.77493167], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.1909173], dtype=float32),
#   'logistic': array([0.1005691], dtype=float32),
#   'probabilities': array([0.89943093, 0.1005691 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.993268], dtype=float32),
#   'logistic': array([0.11991149], dtype=float32),
#   'probabilities': array([0.88008845, 0.11991156], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.2885315], dtype=float32),
#   'logistic': array([0.09207724], dtype=float32),
#   'probabilities': array([0.90792274, 0.09207723], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.5295696], dtype=float32),
#   'logistic': array([0.07381106], dtype=float32),
#   'probabilities': array([0.92618895, 0.07381106], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.2292931], dtype=float32),
#   'logistic': array([0.7736948], dtype=float32),
#   'probabilities': array([0.22630517, 0.7736948 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.516119], dtype=float32),
#   'logistic': array([0.18003374], dtype=float32),
#   'probabilities': array([0.8199663 , 0.18003373], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.87076336], dtype=float32),
#   'logistic': array([0.2950955], dtype=float32),
#   'probabilities': array([0.70490456, 0.2950955 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.17579901], dtype=float32),
#   'logistic': array([0.5438369], dtype=float32),
#   'probabilities': array([0.45616308, 0.5438369 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.0257287], dtype=float32),
#   'logistic': array([0.73608696], dtype=float32),
#   'probabilities': array([0.26391304, 0.736087  ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.398186], dtype=float32),
#   'logistic': array([0.8018959], dtype=float32),
#   'probabilities': array([0.19810411, 0.80189586], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-3.210694], dtype=float32),
#   'logistic': array([0.03876525], dtype=float32),
#   'probabilities': array([0.96123475, 0.03876526], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.2013028], dtype=float32),
#   'logistic': array([0.76875645], dtype=float32),
#   'probabilities': array([0.23124354, 0.76875645], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-3.451661], dtype=float32),
#   'logistic': array([0.03071936], dtype=float32),
#   'probabilities': array([0.9692806 , 0.03071936], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.28947133], dtype=float32),
#   'logistic': array([0.5718667], dtype=float32),
#   'probabilities': array([0.42813328, 0.5718667 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.1115878], dtype=float32),
#   'logistic': array([0.75242496], dtype=float32),
#   'probabilities': array([0.247575, 0.752425], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.8467276], dtype=float32),
#   'logistic': array([0.05485064], dtype=float32),
#   'probabilities': array([0.94514924, 0.05485072], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.44168925], dtype=float32),
#   'logistic': array([0.6086615], dtype=float32),
#   'probabilities': array([0.39133853, 0.6086615 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.38367528], dtype=float32),
#   'logistic': array([0.5947592], dtype=float32),
#   'probabilities': array([0.40524074, 0.5947592 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.6392274], dtype=float32),
#   'logistic': array([0.8374298], dtype=float32),
#   'probabilities': array([0.16257022, 0.8374298 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.097902], dtype=float32),
#   'logistic': array([0.10930088], dtype=float32),
#   'probabilities': array([0.89069915, 0.1093009 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6936193], dtype=float32),
#   'logistic': array([0.15530047], dtype=float32),
#   'probabilities': array([0.84469956, 0.15530047], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.0494323], dtype=float32),
#   'logistic': array([0.11410972], dtype=float32),
#   'probabilities': array([0.88589025, 0.11410975], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.3420751], dtype=float32),
#   'logistic': array([0.79283094], dtype=float32),
#   'probabilities': array([0.20716901, 0.79283094], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.3068702], dtype=float32),
#   'logistic': array([0.7869889], dtype=float32),
#   'probabilities': array([0.21301103, 0.7869889 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.83250135], dtype=float32),
#   'logistic': array([0.69688356], dtype=float32),
#   'probabilities': array([0.30311647, 0.6968836 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.38341516], dtype=float32),
#   'logistic': array([0.40530348], dtype=float32),
#   'probabilities': array([0.5946965 , 0.40530345], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.34971982], dtype=float32),
#   'logistic': array([0.58654964], dtype=float32),
#   'probabilities': array([0.41345036, 0.58654964], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.0829182], dtype=float32),
#   'logistic': array([0.25295419], dtype=float32),
#   'probabilities': array([0.7470458 , 0.25295419], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3874359], dtype=float32),
#   'logistic': array([0.19981742], dtype=float32),
#   'probabilities': array([0.80018264, 0.19981743], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7148961], dtype=float32),
#   'logistic': array([0.32851788], dtype=float32),
#   'probabilities': array([0.67148215, 0.3285179 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9571355], dtype=float32),
#   'logistic': array([0.27745208], dtype=float32),
#   'probabilities': array([0.72254795, 0.2774521 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.6947815], dtype=float32),
#   'logistic': array([0.06328198], dtype=float32),
#   'probabilities': array([0.93671805, 0.06328199], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.3422711], dtype=float32),
#   'logistic': array([0.7928632], dtype=float32),
#   'probabilities': array([0.20713682, 0.7928632 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.4831059], dtype=float32),
#   'logistic': array([0.81504124], dtype=float32),
#   'probabilities': array([0.18495876, 0.81504124], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.4141087], dtype=float32),
#   'logistic': array([0.60207266], dtype=float32),
#   'probabilities': array([0.39792734, 0.60207266], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.8125312], dtype=float32),
#   'logistic': array([0.14033246], dtype=float32),
#   'probabilities': array([0.8596675 , 0.14033248], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5923319], dtype=float32),
#   'logistic': array([0.16905606], dtype=float32),
#   'probabilities': array([0.8309439 , 0.16905606], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.33405772], dtype=float32),
#   'logistic': array([0.41725367], dtype=float32),
#   'probabilities': array([0.5827463 , 0.41725364], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.033977], dtype=float32),
#   'logistic': array([0.2623138], dtype=float32),
#   'probabilities': array([0.73768616, 0.26231378], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.511319], dtype=float32),
#   'logistic': array([0.07506847], dtype=float32),
#   'probabilities': array([0.9249315 , 0.07506848], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3994715], dtype=float32),
#   'logistic': array([0.19789997], dtype=float32),
#   'probabilities': array([0.8021    , 0.19789998], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.0240064], dtype=float32),
#   'logistic': array([0.11670536], dtype=float32),
#   'probabilities': array([0.8832947 , 0.11670537], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-4.1499143], dtype=float32),
#   'logistic': array([0.01552107], dtype=float32),
#   'probabilities': array([0.9844789 , 0.01552107], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-3.4002876], dtype=float32),
#   'logistic': array([0.03228648], dtype=float32),
#   'probabilities': array([0.9677135 , 0.03228648], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.8109099], dtype=float32),
#   'logistic': array([0.69230336], dtype=float32),
#   'probabilities': array([0.30769664, 0.69230336], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.0159023], dtype=float32),
#   'logistic': array([0.11754334], dtype=float32),
#   'probabilities': array([0.8824566 , 0.11754337], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-3.1767998], dtype=float32),
#   'logistic': array([0.04004818], dtype=float32),
#   'probabilities': array([0.9599518 , 0.04004819], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-3.7105675], dtype=float32),
#   'logistic': array([0.02387944], dtype=float32),
#   'probabilities': array([0.97612053, 0.02387946], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.0645897], dtype=float32),
#   'logistic': array([0.7435667], dtype=float32),
#   'probabilities': array([0.2564333 , 0.74356663], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.5734417], dtype=float32),
#   'logistic': array([0.63955694], dtype=float32),
#   'probabilities': array([0.36044306, 0.63955694], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.4857419], dtype=float32),
#   'logistic': array([0.18456173], dtype=float32),
#   'probabilities': array([0.81543833, 0.18456173], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.6907847], dtype=float32),
#   'logistic': array([0.33385855], dtype=float32),
#   'probabilities': array([0.6661415 , 0.33385855], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7835824], dtype=float32),
#   'logistic': array([0.14386134], dtype=float32),
#   'probabilities': array([0.8561387 , 0.14386134], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0443804], dtype=float32),
#   'logistic': array([0.26030567], dtype=float32),
#   'probabilities': array([0.73969436, 0.26030567], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.1823814], dtype=float32),
#   'logistic': array([0.76537573], dtype=float32),
#   'probabilities': array([0.23462427, 0.7653757 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.42434502], dtype=float32),
#   'logistic': array([0.3954775], dtype=float32),
#   'probabilities': array([0.60452247, 0.39547744], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.124964], dtype=float32),
#   'logistic': array([0.10669404], dtype=float32),
#   'probabilities': array([0.893306  , 0.10669404], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.3038969], dtype=float32),
#   'logistic': array([0.7864901], dtype=float32),
#   'probabilities': array([0.2135099, 0.7864901], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.75897455], dtype=float32),
#   'logistic': array([0.68113106], dtype=float32),
#   'probabilities': array([0.31886894, 0.68113106], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.0167761], dtype=float32),
#   'logistic': array([0.7343441], dtype=float32),
#   'probabilities': array([0.26565588, 0.7343442 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.74176556], dtype=float32),
#   'logistic': array([0.3226182], dtype=float32),
#   'probabilities': array([0.6773818, 0.3226182], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.6353798], dtype=float32),
#   'logistic': array([0.8369053], dtype=float32),
#   'probabilities': array([0.16309471, 0.8369053 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.9348583], dtype=float32),
#   'logistic': array([0.1262138], dtype=float32),
#   'probabilities': array([0.8737862 , 0.12621382], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4928339], dtype=float32),
#   'logistic': array([0.18349676], dtype=float32),
#   'probabilities': array([0.8165032 , 0.18349676], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.3885808], dtype=float32),
#   'logistic': array([0.08404762], dtype=float32),
#   'probabilities': array([0.9159524 , 0.08404762], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.2889705], dtype=float32),
#   'logistic': array([0.78397286], dtype=float32),
#   'probabilities': array([0.21602713, 0.7839729 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.36575884], dtype=float32),
#   'logistic': array([0.5904338], dtype=float32),
#   'probabilities': array([0.40956625, 0.5904338 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.7017952], dtype=float32),
#   'logistic': array([0.66858566], dtype=float32),
#   'probabilities': array([0.3314143 , 0.66858566], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.4519029], dtype=float32),
#   'logistic': array([0.18970892], dtype=float32),
#   'probabilities': array([0.8102912 , 0.18970889], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.666776], dtype=float32),
#   'logistic': array([0.15885448], dtype=float32),
#   'probabilities': array([0.8411455, 0.1588545], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6611183], dtype=float32),
#   'logistic': array([0.15961191], dtype=float32),
#   'probabilities': array([0.84038806, 0.15961194], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9656498], dtype=float32),
#   'logistic': array([0.27574843], dtype=float32),
#   'probabilities': array([0.72425157, 0.27574843], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.8794065], dtype=float32),
#   'logistic': array([0.05318101], dtype=float32),
#   'probabilities': array([0.946819  , 0.05318101], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.4262104], dtype=float32),
#   'logistic': array([0.08119573], dtype=float32),
#   'probabilities': array([0.9188043 , 0.08119573], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-4.011013], dtype=float32),
#   'logistic': array([0.0177927], dtype=float32),
#   'probabilities': array([0.9822073 , 0.01779272], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.2945914], dtype=float32),
#   'logistic': array([0.7849233], dtype=float32),
#   'probabilities': array([0.21507667, 0.7849233 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.9821221], dtype=float32),
#   'logistic': array([0.72752905], dtype=float32),
#   'probabilities': array([0.2724709 , 0.72752905], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.4877975], dtype=float32),
#   'logistic': array([0.8157475], dtype=float32),
#   'probabilities': array([0.18425255, 0.8157475 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.15187448], dtype=float32),
#   'logistic': array([0.5378958], dtype=float32),
#   'probabilities': array([0.4621042, 0.5378958], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.19182299], dtype=float32),
#   'logistic': array([0.45219076], dtype=float32),
#   'probabilities': array([0.54780924, 0.4521908 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.5097272], dtype=float32),
#   'logistic': array([0.81902075], dtype=float32),
#   'probabilities': array([0.1809792 , 0.81902075], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-3.2412248], dtype=float32),
#   'logistic': array([0.03764346], dtype=float32),
#   'probabilities': array([0.96235657, 0.0376435 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.0284014], dtype=float32),
#   'logistic': array([0.7366058], dtype=float32),
#   'probabilities': array([0.26339412, 0.7366058 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.8858488], dtype=float32),
#   'logistic': array([0.7080328], dtype=float32),
#   'probabilities': array([0.29196724, 0.7080328 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.9544502], dtype=float32),
#   'logistic': array([0.27799076], dtype=float32),
#   'probabilities': array([0.72200924, 0.27799073], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.13068703], dtype=float32),
#   'logistic': array([0.5326253], dtype=float32),
#   'probabilities': array([0.46737465, 0.5326253 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.424236], dtype=float32),
#   'logistic': array([0.19399837], dtype=float32),
#   'probabilities': array([0.80600166, 0.19399837], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.30855328], dtype=float32),
#   'logistic': array([0.57653207], dtype=float32),
#   'probabilities': array([0.42346793, 0.5765321 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.4640851], dtype=float32),
#   'logistic': array([0.1878433], dtype=float32),
#   'probabilities': array([0.8121567 , 0.18784332], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.0598466], dtype=float32),
#   'logistic': array([0.74266124], dtype=float32),
#   'probabilities': array([0.25733876, 0.74266124], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.43530726], dtype=float32),
#   'logistic': array([0.39285973], dtype=float32),
#   'probabilities': array([0.60714024, 0.3928597 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.15938559], dtype=float32),
#   'logistic': array([0.46023774], dtype=float32),
#   'probabilities': array([0.53976226, 0.46023774], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.0993106], dtype=float32),
#   'logistic': array([0.10916384], dtype=float32),
#   'probabilities': array([0.8908362 , 0.10916384], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.4339167], dtype=float32),
#   'logistic': array([0.3931915], dtype=float32),
#   'probabilities': array([0.60680854, 0.39319146], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0034087], dtype=float32),
#   'logistic': array([0.26827174], dtype=float32),
#   'probabilities': array([0.73172826, 0.26827177], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.8346543], dtype=float32),
#   'logistic': array([0.30266184], dtype=float32),
#   'probabilities': array([0.6973381 , 0.30266184], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.9907107], dtype=float32),
#   'logistic': array([0.0478473], dtype=float32),
#   'probabilities': array([0.95215267, 0.0478473 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.7815876], dtype=float32),
#   'logistic': array([0.8558928], dtype=float32),
#   'probabilities': array([0.14410722, 0.85589284], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.15815082], dtype=float32),
#   'logistic': array([0.5394555], dtype=float32),
#   'probabilities': array([0.46054447, 0.5394555 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.13124141], dtype=float32),
#   'logistic': array([0.53276336], dtype=float32),
#   'probabilities': array([0.4672367 , 0.53276336], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.9901326], dtype=float32),
#   'logistic': array([0.04787365], dtype=float32),
#   'probabilities': array([0.9521263 , 0.04787365], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.64644], dtype=float32),
#   'logistic': array([0.8384093], dtype=float32),
#   'probabilities': array([0.16159067, 0.8384093 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.32374758], dtype=float32),
#   'logistic': array([0.5802373], dtype=float32),
#   'probabilities': array([0.41976273, 0.5802373 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.3884668], dtype=float32),
#   'logistic': array([0.19965263], dtype=float32),
#   'probabilities': array([0.8003474 , 0.19965264], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.00378925], dtype=float32),
#   'logistic': array([0.5009473], dtype=float32),
#   'probabilities': array([0.49905267, 0.5009473 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.9527256], dtype=float32),
#   'logistic': array([0.87574357], dtype=float32),
#   'probabilities': array([0.12425645, 0.8757435 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-3.0436025], dtype=float32),
#   'logistic': array([0.04549447], dtype=float32),
#   'probabilities': array([0.95450556, 0.04549448], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.82902783], dtype=float32),
#   'logistic': array([0.6961493], dtype=float32),
#   'probabilities': array([0.30385068, 0.69614935], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.4518394], dtype=float32),
#   'logistic': array([0.18971863], dtype=float32),
#   'probabilities': array([0.81028134, 0.18971863], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.889993], dtype=float32),
#   'logistic': array([0.13124529], dtype=float32),
#   'probabilities': array([0.86875474, 0.13124527], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.3784165], dtype=float32),
#   'logistic': array([0.08483338], dtype=float32),
#   'probabilities': array([0.91516656, 0.08483342], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.03798404], dtype=float32),
#   'logistic': array([0.49050513], dtype=float32),
#   'probabilities': array([0.5094949 , 0.49050516], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.40559423], dtype=float32),
#   'logistic': array([0.39996904], dtype=float32),
#   'probabilities': array([0.60003096, 0.399969  ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-3.396717], dtype=float32),
#   'logistic': array([0.03239822], dtype=float32),
#   'probabilities': array([0.9676018 , 0.03239822], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.5947275], dtype=float32),
#   'logistic': array([0.83128023], dtype=float32),
#   'probabilities': array([0.16871981, 0.8312802 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.0584826], dtype=float32),
#   'logistic': array([0.74240047], dtype=float32),
#   'probabilities': array([0.25759953, 0.74240047], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.39929754], dtype=float32),
#   'logistic': array([0.59851885], dtype=float32),
#   'probabilities': array([0.40148112, 0.59851885], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.8752597], dtype=float32),
#   'logistic': array([0.7058389], dtype=float32),
#   'probabilities': array([0.29416105, 0.705839  ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-4.631784], dtype=float32),
#   'logistic': array([0.00964352], dtype=float32),
#   'probabilities': array([0.9903565 , 0.00964347], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.2691963], dtype=float32),
#   'logistic': array([0.09370646], dtype=float32),
#   'probabilities': array([0.9062936 , 0.09370644], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7779512], dtype=float32),
#   'logistic': array([0.14455625], dtype=float32),
#   'probabilities': array([0.8554438 , 0.14455631], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9452781], dtype=float32),
#   'logistic': array([0.27983546], dtype=float32),
#   'probabilities': array([0.7201646 , 0.27983543], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.0800524], dtype=float32),
#   'logistic': array([0.74650395], dtype=float32),
#   'probabilities': array([0.2534961 , 0.74650395], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.553406], dtype=float32),
#   'logistic': array([0.6349254], dtype=float32),
#   'probabilities': array([0.36507455, 0.6349254 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.3074694], dtype=float32),
#   'logistic': array([0.7870894], dtype=float32),
#   'probabilities': array([0.21291061, 0.78708935], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.39828265], dtype=float32),
#   'logistic': array([0.40172502], dtype=float32),
#   'probabilities': array([0.598275  , 0.40172502], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3745327], dtype=float32),
#   'logistic': array([0.2018885], dtype=float32),
#   'probabilities': array([0.79811144, 0.20188849], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.0599406], dtype=float32),
#   'logistic': array([0.11305177], dtype=float32),
#   'probabilities': array([0.8869482 , 0.11305179], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9834883], dtype=float32),
#   'logistic': array([0.12094742], dtype=float32),
#   'probabilities': array([0.87905246, 0.12094746], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.5472316], dtype=float32),
#   'logistic': array([0.63349307], dtype=float32),
#   'probabilities': array([0.36650693, 0.63349307], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-4.2924733], dtype=float32),
#   'logistic': array([0.01348665], dtype=float32),
#   'probabilities': array([0.9865133 , 0.01348669], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.3024728], dtype=float32),
#   'logistic': array([0.09091836], dtype=float32),
#   'probabilities': array([0.90908164, 0.09091837], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.7564532], dtype=float32),
#   'logistic': array([0.68058324], dtype=float32),
#   'probabilities': array([0.31941682, 0.68058324], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.577749], dtype=float32),
#   'logistic': array([0.6405493], dtype=float32),
#   'probabilities': array([0.3594507, 0.6405493], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.83432025], dtype=float32),
#   'logistic': array([0.30273238], dtype=float32),
#   'probabilities': array([0.69726765, 0.30273235], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.18720692], dtype=float32),
#   'logistic': array([0.5466655], dtype=float32),
#   'probabilities': array([0.45333448, 0.5466655 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.9702248], dtype=float32),
#   'logistic': array([0.7251643], dtype=float32),
#   'probabilities': array([0.2748357, 0.7251643], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.6384258], dtype=float32),
#   'logistic': array([0.06670597], dtype=float32),
#   'probabilities': array([0.933294  , 0.06670597], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.284854], dtype=float32),
#   'logistic': array([0.09238514], dtype=float32),
#   'probabilities': array([0.9076149 , 0.09238515], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.3246269], dtype=float32),
#   'logistic': array([0.7899505], dtype=float32),
#   'probabilities': array([0.21004952, 0.7899505 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.77009344], dtype=float32),
#   'logistic': array([0.6835411], dtype=float32),
#   'probabilities': array([0.3164589, 0.6835411], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.5002558], dtype=float32),
#   'logistic': array([0.81761265], dtype=float32),
#   'probabilities': array([0.18238735, 0.8176126 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.76037705], dtype=float32),
#   'logistic': array([0.6814356], dtype=float32),
#   'probabilities': array([0.31856441, 0.6814356 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.24201491], dtype=float32),
#   'logistic': array([0.43978986], dtype=float32),
#   'probabilities': array([0.56021017, 0.43978986], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3467352], dtype=float32),
#   'logistic': array([0.20640466], dtype=float32),
#   'probabilities': array([0.7935954 , 0.20640463], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.5017908], dtype=float32),
#   'logistic': array([0.6228801], dtype=float32),
#   'probabilities': array([0.37711993, 0.6228801 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.2946322], dtype=float32),
#   'logistic': array([0.0915685], dtype=float32),
#   'probabilities': array([0.9084315 , 0.09156849], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.915493], dtype=float32),
#   'logistic': array([0.05139297], dtype=float32),
#   'probabilities': array([0.948607  , 0.05139298], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.431096], dtype=float32),
#   'logistic': array([0.08083197], dtype=float32),
#   'probabilities': array([0.91916806, 0.080832  ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.13575563], dtype=float32),
#   'logistic': array([0.5338869], dtype=float32),
#   'probabilities': array([0.46611312, 0.5338869 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-4.427672], dtype=float32),
#   'logistic': array([0.01180133], dtype=float32),
#   'probabilities': array([0.98819864, 0.01180132], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7219853], dtype=float32),
#   'logistic': array([0.15161559], dtype=float32),
#   'probabilities': array([0.84838444, 0.15161563], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.1118245], dtype=float32),
#   'logistic': array([0.10795285], dtype=float32),
#   'probabilities': array([0.89204717, 0.10795284], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.673285], dtype=float32),
#   'logistic': array([0.06456827], dtype=float32),
#   'probabilities': array([0.93543166, 0.06456827], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.374248], dtype=float32),
#   'logistic': array([0.20193437], dtype=float32),
#   'probabilities': array([0.7980656 , 0.20193437], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.36602217], dtype=float32),
#   'logistic': array([0.59049743], dtype=float32),
#   'probabilities': array([0.40950254, 0.59049743], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.2674947], dtype=float32),
#   'logistic': array([0.7803136], dtype=float32),
#   'probabilities': array([0.21968642, 0.78031355], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.9111471], dtype=float32),
#   'logistic': array([0.12885201], dtype=float32),
#   'probabilities': array([0.871148  , 0.12885204], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.7942595], dtype=float32),
#   'logistic': array([0.05763519], dtype=float32),
#   'probabilities': array([0.9423649 , 0.05763517], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.29019517], dtype=float32),
#   'logistic': array([0.5720439], dtype=float32),
#   'probabilities': array([0.42795607, 0.5720439 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.1018033], dtype=float32),
#   'logistic': array([0.2494022], dtype=float32),
#   'probabilities': array([0.75059783, 0.24940217], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.8933938], dtype=float32),
#   'logistic': array([0.70959], dtype=float32),
#   'probabilities': array([0.29040995, 0.70959   ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.44526088], dtype=float32),
#   'logistic': array([0.60951185], dtype=float32),
#   'probabilities': array([0.39048812, 0.60951185], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.9519894], dtype=float32),
#   'logistic': array([0.04964257], dtype=float32),
#   'probabilities': array([0.9503574 , 0.04964257], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.7174067], dtype=float32),
#   'logistic': array([0.67203575], dtype=float32),
#   'probabilities': array([0.32796434, 0.67203575], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)}]

# %%
'logits': array([0.12879157], dtype=float32),
  'logistic': array([0.5321534], dtype=float32),
  'probabilities': array([0.46784657, 0.5321535 ], dtype=float32),
  'class_ids': array([1]),
  'classes': array([b'1'], dtype=object)},
 {'logits': array([0.5740763], dtype=float32),
  'logistic': array([0.6397032], dtype=float32),
  'probabilities': array([0.3602968, 0.6397033], dtype=float32),
  'class_ids': array([1]),
  'classes': array([b'1'], dtype=object)},
 {'logits': array([-0.4880718], dtype=float32),
  'logistic': array([0.3803479], dtype=float32),
  'probabilities': array([0.6196521, 0.3803479], dtype=float32),
  'class_ids': array([0]),
  'classes': array([b'0'], dtype=object)},
 {'logits': array([-0.5959315], dtype=float32),
